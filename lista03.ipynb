# %% [markdown]
# # Aula 03 - Álgebra Linear

# %% [markdown]
# # Exercício 01:
#
# Crie uma matriz `n x m` com valores aleatórios entre 0 e 1. Use uma semente global (_seed_) igual a 10.

# %%
from random import uniform
from random import seed

#Exemplo:
n = 10
m = 5

# YOUR CODE HERE
seed(10)

matrix = [[uniform(0,1) for j in range(m)] for i in range(n)]
print(matrix)
# Out:
# [[0.5714025946899135, 0.4288890546751146, 0.5780913011344704, 0.20609823213950174, 0.81332125135732], [0.8235888725334455, 0.6534725339011758, 0.16022955651881965, 0.5206693596399246, 0.32777281162209315], [0.24999667668640035, 0.9528169091459117, 0.9965569925394552, 0.04455638245043303, 0.860161037286291], [0.603190610968185, 0.3816059859191179, 0.28361821790671515, 0.674964847134956, 0.45683115105830563], [0.6858614854745947, 0.6618463200523511, 0.1329781447122128, 0.7678378139439905, 0.9824132490111909], [0.9693881604049188, 0.613326820546709, 0.0442606328646209, 0.004055144158407464, 0.13397252704913387], [0.941002271395834, 0.3028605620290723, 0.3661456016604264, 0.8981962445391883, 0.31436380495645067], [0.5489821840124055, 0.43603095762412225, 0.06499417612685054, 0.5845462257019302, 0.8440678976619022], [0.1564189183874064, 0.2242989686860415, 0.41287020771484073, 0.03692486905862902, 0.4966034986165482], [0.8179828644296319, 0.6578909387591091, 0.5334837356527721, 0.8551257407736, 0.14968813497140154]]

# %% [markdown]
# # Exercício 02:
#
# Considere que matrizes `n x m` são listas contendo `n` vetores de tamanho `m`. Mostre visualmente a diferença entre a funções de distância Euclidiana e de cosseno. Para isso, use a matriz criada no exercício anterior e calcule a distância entre todos os pares de vetores $u$ e $v$ ($u \neq $v) dessa matriz. Para visualizar as diferenças, plote o gráfico de dispersão das distâncias, ou seja, no eixo `x` teremos a distância Euclidiana e no eixo `y` a distância de cosseno para cada par de vetores $u$ e $v$.

# %%
import matplotlib.pyplot as plt
import math

#Exemplo:
n = 10
m = 10

# YOUR CODE HERE
def dot(v, w):
    return sum(v_i * w_i
        for v_i, w_i in zip(v, w))

def sum_of_squares(v):
    return dot(v, v)

def vector_subtract(v, w):
    return [v_i - w_i
        for v_i, w_i in zip(v, w)]

def squared_distance(v, w):
    return sum_of_squares(vector_subtract(v, w))


# distância euclidiana
def distance(v, w):
    return math.sqrt(squared_distance(v, w))


# distância de cossenos
def cosine_similarity(v, w):
    return dot(v, w) / math.sqrt(dot(v, v) * dot(w, w))

def cosine_distance(v, w):
    return 1 - cosine_similarity(v,w)

# gráfico 
euclidiana = []
cosseno = []

for row1 in matrix:
    for row2 in matrix:
        if row1 != row2:
            euclidiana.append(distance(row1, row2))
            cosseno.append(cosine_distance(row1, row2))

plt.scatter(euclidiana, cosseno)
plt.title('Distâncias Euclidiana e de Cossenos')
plt.xlabel('Distância Euclidiana')
plt.ylabel('Distância de Cossenos')

plt.show()
# Out:
# [0.7895292122988823, 0.7623683036747679, 0.6609702395600344, 0.7807938963826135, 0.9898086082686532, 0.9619596008106418, 0.6387414041489506, 0.6085197829738946, 0.9883719681197995, 0.7895292122988823, 1.276001344921807, 0.422107483718458, 0.7137422083315991, 0.5837522589559928, 0.5672939528857367, 0.6343503133438978, 0.9775712395883092, 0.5319256102201934, 0.7623683036747679, 1.276001344921807, 1.2326392010123894, 1.2483958002520874, 1.4382753861682458, 1.524449454653403, 1.231307172951413, 1.006189730179802, 1.3363461034834876, 0.6609702395600344, 0.422107483718458, 1.2326392010123894, 0.6268360867653314, 0.8941167510880982, 0.4441368373216666, 0.46024442176332947, 0.80606040287658, 0.5582979887112103, 0.7807938963826135, 0.7137422083315991, 1.2483958002520874, 0.6268360867653314, 1.1806049040581024, 0.8435745599606731, 0.3564906501189616, 1.1490611515680564, 0.937510922558022, 0.9898086082686532, 0.5837522589559928, 1.4382753861682458, 0.8941167510880982, 1.1806049040581024, 1.0162845615498846, 1.024602468730906, 1.039575065599429, 0.9943927339529314, 0.9619596008106418, 0.5672939528857367, 1.524449454653403, 0.4441368373216666, 0.8435745599606731, 1.0162845615498846, 0.8006678739786404, 1.182761953541364, 0.44514664837452667, 0.6387414041489506, 0.6343503133438978, 1.231307172951413, 0.46024442176332947, 0.3564906501189616, 1.024602468730906, 0.8006678739786404, 0.8605665255324809, 0.9468063231144347, 0.6085197829738946, 0.9775712395883092, 1.006189730179802, 0.80606040287658, 1.1490611515680564, 1.039575065599429, 1.182761953541364, 0.8605665255324809, 1.1958341901554, 0.9883719681197995, 0.5319256102201934, 1.3363461034834876, 0.5582979887112103, 0.937510922558022, 0.9943927339529314, 0.44514664837452667, 0.9468063231144347, 1.1958341901554]
# [0.203770515235153, 0.10282090151369105, 0.15117797858505877, 0.12762787399447129, 0.33785625478635284, 0.2530671181155867, 0.13167444763032188, 0.04370126254483897, 0.25518500850848647, 0.203770515235153, 0.35999516299069534, 0.06045043271623618, 0.10061309386884598, 0.11811794655086716, 0.0817086252884307, 0.13145348572908133, 0.3932372633422411, 0.06343813978877622, 0.10282090151369105, 0.35999516299069534, 0.3376446638820706, 0.2998519400148201, 0.481190926118946, 0.48664649348416356, 0.3311653874863223, 0.053722310300504894, 0.36421166195740784, 0.15117797858505877, 0.06045043271623618, 0.3376446638820706, 0.05265105854439622, 0.3083245554959615, 0.033670344953743325, 0.07035898972082766, 0.30218727232829046, 0.05921421001214022, 0.12762787399447129, 0.10061309386884598, 0.2998519400148201, 0.05265105854439622, 0.334543313066203, 0.15370314490837467, 0.004615387472273191, 0.2524978687720124, 0.18799272663164368, 0.33785625478635284, 0.11811794655086716, 0.481190926118946, 0.3083245554959615, 0.334543313066203, 0.2933303759610656, 0.3620420690845624, 0.5390439952891202, 0.2645085940968235, 0.2530671181155867, 0.0817086252884307, 0.48664649348416356, 0.033670344953743325, 0.15370314490837467, 0.2933303759610656, 0.172613839389681, 0.4429625408454678, 0.04724838906002615, 0.13167444763032188, 0.13145348572908133, 0.3311653874863223, 0.07035898972082766, 0.004615387472273191, 0.3620420690845624, 0.172613839389681, 0.2551208126400134, 0.23305882765295105, 0.04370126254483897, 0.3932372633422411, 0.053722310300504894, 0.30218727232829046, 0.2524978687720124, 0.5390439952891202, 0.4429625408454678, 0.2551208126400134, 0.4143682618654114, 0.25518500850848647, 0.06343813978877622, 0.36421166195740784, 0.05921421001214022, 0.18799272663164368, 0.2645085940968235, 0.04724838906002615, 0.23305882765295105, 0.4143682618654114]
